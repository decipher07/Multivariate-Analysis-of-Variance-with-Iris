# %%
import numpy as np
import pandas as pd
from statsmodels.multivariate.manova import MANOVA
url ='https://vincentarelbundock.github.io/Rdatasets/csv/datasets/iris.csv'
df = pd.read_csv(url, index_col=0)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9          3.0           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1 = pd.read_csv(url)
df1
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df.columns = df.columns.str.replace(".", "_") 
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9          3.0           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
# In this MANOVA example, we are going to use the width and length columns as dependent variables. Furthermore, the species column is used as independent variable. That is, we are carrying out a one-way MANOVA here:
maov = MANOVA.from_formula('Sepal_Length + Sepal_Width + Petal_Length + Petal_Width ~ Species', data=df)
print(maov)

# %%
print(maov.mv_test())
# Out:
#                    Multivariate linear model
# ...
#
# ----------------------------------------------------------------
#        Intercept         Value  Num DF  Den DF   F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda  0.0170 4.0000 144.0000 2086.7720 0.0000
#          Pillai's trace  0.9830 4.0000 144.0000 2086.7720 0.0000
#  Hotelling-Lawley trace 57.9659 4.0000 144.0000 2086.7720 0.0000
#     Roy's greatest root 57.9659 4.0000 144.0000 2086.7720 0.0000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
#         Species          Value  Num DF  Den DF   F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda  0.0234 8.0000 288.0000  199.1453 0.0000
#          Pillai's trace  1.1919 8.0000 290.0000   53.4665 0.0000
#  Hotelling-Lawley trace 32.4773 8.0000 203.4024  582.1970 0.0000
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.multivariate.manova import MANOVA
from statsmodels.stats.multicomp import pairwise_tukeyhsd 

df = pd.read_csv('WineQuality.csv')
df=df.dropna ()
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
maov = MANOVA.from_formula('pH + sulphates~quality',data=df)
print(maov.mv_test())
# Out:
#                     Multivariate linear model
# ...
#
# -----------------------------------------------------------------
#        Intercept         Value  Num DF   Den DF   F Value  Pr > F
# -----------------------------------------------------------------
#           Wilks' lambda  0.0872 2.0000 1596.0000 8356.0474 0.0000
#          Pillai's trace  0.9128 2.0000 1596.0000 8356.0474 0.0000
#  Hotelling-Lawley trace 10.4712 2.0000 1596.0000 8356.0474 0.0000
#     Roy's greatest root 10.4712 2.0000 1596.0000 8356.0474 0.0000
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#            quality         Value  Num DF   Den DF  F Value Pr > F
# -----------------------------------------------------------------
#              Wilks' lambda 0.9367 2.0000 1596.0000 53.9016 0.0000
#             Pillai's trace 0.0633 2.0000 1596.0000 53.9016 0.0000
# ...

# %%
reg=ols('pH~quality',data=df).fit()
aov=sm.stats.anova_lm(reg,type=2)
print(aov)
# Out:
#               df     sum_sq   mean_sq         F    PR(>F)
# quality      1.0   0.126946  0.126946  5.340462  0.020963
# Residual  1597.0  37.961672  0.023771       NaN       NaN

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.multivariate.manova import MANOVA
from statsmodels.stats.multicomp import pairwise_tukeyhsd

df = pd.read_csv('WineQuality.csv')
maov = MANOVA.from_formula('pH +sulphates~quality+alcohol',data=df)
print(maov.mv_test())
# Out:
#                    Multivariate linear model
# ...
#
# ----------------------------------------------------------------
#        Intercept        Value  Num DF   Den DF   F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda 0.1811 2.0000 1595.0000 3606.6776 0.0000
#          Pillai's trace 0.8189 2.0000 1595.0000 3606.6776 0.0000
#  Hotelling-Lawley trace 4.5225 2.0000 1595.0000 3606.6776 0.0000
#     Roy's greatest root 4.5225 2.0000 1595.0000 3606.6776 0.0000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
#           quality         Value  Num DF   Den DF  F Value Pr > F
# ----------------------------------------------------------------
#             Wilks' lambda 0.9268 2.0000 1595.0000 62.9702 0.0000
#            Pillai's trace 0.0732 2.0000 1595.0000 62.9702 0.0000
#    Hotelling-Lawley trace 0.0790 2.0000 1595.0000 62.9702 0.0000
# ...

# %%
reg=ols('pH~quality+alcohol',data=df).fit()
aov=sm.stats.anova_lm(reg,type=2)
print(aov)
# Out:
#               df     sum_sq   mean_sq           F        PR(>F)
# quality      1.0   0.126946  0.126946    5.742024  1.667820e-02
# alcohol      1.0   2.676911  2.676911  121.082026  3.386040e-27
# Residual  1596.0  35.284761  0.022108         NaN           NaN

# %%
reg=ols('sulphates~quality+alcohol',data=df).fit()
aov=sm.stats.anova_lm(reg,type=2)
print(aov)
# Out:
#               df     sum_sq   mean_sq           F        PR(>F)
# quality      1.0   2.901833  2.901833  107.774412  1.775265e-24
# alcohol      1.0   0.040486  0.040486    1.503658  2.202902e-01
# Residual  1596.0  42.972402  0.026925         NaN           NaN
